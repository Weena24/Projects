# %% [markdown]
# ### Feature Selection Techniques

# %%
import pandas as pd

# %%
df=pd.read_csv('mobile_dataset.csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %% [markdown]
# ### Univariate Selection

# %%
X=df.iloc[:,:-1] #take all rows except last one ---> independent features
y=df['price_range'] # dependent variable

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest   #which features you want
from sklearn.feature_selection import chi2

# %%
### Apply KBest algorithm
ordered_rank_features=SelectKBest(score_func=chi2,k=20)
ordered_feature=ordered_rank_features.fit(X,y)

# %%
ordered_feature
# Out:
# SelectKBest(k=20, score_func=<function chi2 at 0x00000200493ED940>)

# %%
pd.DataFrame(ordered_feature.scores_,columns=['Score'])
# Out:
#             Score
# 0    14129.866576
# 1        0.723232
# 2        0.648366
# 3        0.631011
# 4       10.135166
# 5        1.521572
# 6       89.839124
# 7        0.745820
# 8       95.972863
# 9        9.097556
# 10       9.186054
# 11   17363.569536
# 12    9810.586750
# 13  931267.519053
# 14       9.614878
# 15      16.480319
# 16      13.236400
# 17       0.327643
# 18       1.928429
# 19       0.422091

# %%
dfscores=pd.DataFrame(ordered_feature.scores_,columns=['Score'])
dfcolumns=pd.DataFrame(X.columns)

# %%
features_rank=pd.concat([dfcolumns,dfscores],axis=1)

# %%
features_rank.columns=['Features','Score']
features_rank
# Out:
#          Features          Score
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
#top 10 features wrt univariate selection
features_rank.nlargest(10,'Score')
# Out:
#          Features          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# ### Feature Importance
# This technique gives you a score for each feature of your data, the higher the score, more relevant it is

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

# %%
model=ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.06117359 0.01926558 0.03300527 0.02019356 0.03262984 0.01778278
#  0.03585103 0.03417078 0.03589638 0.0321287  0.03291488 0.04700077
#  0.04854737 0.39450569 0.0339804  0.03400282 0.03471707 0.01432714
#  0.01794112 0.01996523]

# %%
ranked_feature=pd.Series(model.feature_importances_,index=X.columns)

# %%
ranked_feature.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# ### Correlation

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
corr=df.corr()

# %%
top_features=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df[top_features].corr(),annot=True)
# Out:
# <Axes: >

# %%
### price is removed here
### 3G and 4G are highly correlated - both features are doing the same task - can drop one of them 
corr=df.iloc[:,:-1].corr()
top_features=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df[top_features].corr(),annot=True)
# Out:
# <Axes: >

# %%
#whichever feature has a correlation value of 0.8, more than 80%, drop that feature 
threshold=0.5

# %%
### Remove the correlated features which are correlated among themselves (independent features)
#find and remove correlated features
def correlation(dataset, threshold):
    col_corr = set() #Set of all names of correlated columns --- create a set that is unique values 
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)): #iterating from y side and x side from heatmap
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: #if threshold is >0.5.... (0.5 is selected according to domain expert)
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
    return col_corr #correlated columns

# %%
#highly correlated features displayed based on threshold value
correlation(df.iloc[:,:-1],threshold)
# Out:
# {'pc', 'px_width', 'sc_w', 'three_g'}
